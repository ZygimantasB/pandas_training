# %%
# %%sql
# SELECT * FROM employees;
# Out:
#    EmployeeId  LastName FirstName                Title  ReportsTo  \
# 0           1     Adams    Andrew      General Manager        NaN
# 1           2   Edwards     Nancy        Sales Manager        1.0
# 2           3   Peacock      Jane  Sales Support Agent        2.0
# 3           4      Park  Margaret  Sales Support Agent        2.0
# 4           5   Johnson     Steve  Sales Support Agent        2.0
# 5           6  Mitchell   Michael           IT Manager        1.0
# 6           7      King    Robert             IT Staff        6.0
# 7           8  Callahan     Laura             IT Staff        6.0
#
#              BirthDate             HireDate                      Address  \
# 0  1962-02-18 00:00:00  2002-08-14 00:00:00          11120 Jasper Ave NW
# 1  1958-12-08 00:00:00  2002-05-01 00:00:00                 825 8 Ave SW
# 2  1973-08-29 00:00:00  2002-04-01 00:00:00                1111 6 Ave SW
# 3  1947-09-19 00:00:00  2003-05-03 00:00:00             683 10 Street SW
# ...

# %%
# %%sql
# SELECT Name, COUNT(Name) FROM artists
# GROUP BY Name;
# Out:
#                                                   Name  COUNT(Name)
# 0                                         A Cor Do Som            1
# 1                                                AC/DC            1
# 2            Aaron Copland & London Symphony Orchestra            1
# 3                                       Aaron Goldberg            1
# 4    Academy of St. Martin in the Fields & Sir Nevi...            1
# ..                                                 ...          ...
# 270                                                Xis            1
# 271                                     Yehudi Menuhin            1
# 272                                           Yo-Yo Ma            1
# 273                                     Youssou N'Dour            1
# 274                                     Zeca Pagodinho            1
#
# [275 rows x 2 columns]

# %%
# %%sql
# -- SELECT * FROM invoices;
# SELECT BillingCountry, SUM(Total) as Total_sum FROM invoices
# GROUP BY BillingCountry ORDER BY Total_sum ASC;
# Out:
#     BillingCountry  Total_sum
# 0        Argentina      37.62
# 1        Australia      37.62
# 2          Belgium      37.62
# 3          Denmark      37.62
# 4            Italy      37.62
# 5           Poland      37.62
# 6            Spain      37.62
# 7           Sweden      38.62
# 8           Norway      39.62
# 9      Netherlands      40.62
# 10         Finland      41.62
# 11         Austria      42.62
# 12         Hungary      45.62
# 13         Ireland      45.62
# 14           Chile      46.62
# 15           India      75.26
# 16        Portugal      77.24
# 17  Czech Republic      90.24
# 18  United Kingdom     112.86
# 19         Germany     156.48
# 20          Brazil     190.10
# 21          France     195.10
# 22          Canada     303.96
# 23             USA     523.06

# %%
# %%sql
# SELECT * FROM genres
# INNER JOIN main.tracks t on genres.GenreId = t.GenreId;
# Out:
#       GenreId       Name  TrackId  \
# 0           1       Rock        1
# 1           1       Rock        2
# 2           1       Rock        3
# 3           1       Rock        4
# 4           1       Rock        5
# ...       ...        ...      ...
# 3498       24  Classical     3499
# 3499       24  Classical     3500
# 3500       24  Classical     3501
# 3501       24  Classical     3502
# 3502       25      Opera     3451
#
#                                                  Name.1  AlbumId  MediaTypeId  \
# 0               For Those About To Rock (We Salute You)        1            1
# 1                                     Balls to the Wall        2            2
# 2                                       Fast As a Shark        3            2
# 3                                     Restless and Wild        3            2
# 4                                  Princess of the Dawn        3            2
# ...                                                 ...      ...          ...
# ...
