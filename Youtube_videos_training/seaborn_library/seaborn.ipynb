# %% [markdown]
# https://www.youtube.com/watch?v=6GUZXDef2U0

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# computer_sales_path = r'

# %%
computer_sales_path = r'F:\DataSpell\Pandas_training\Youtube_videos_training\seaborn_library\data\ComputerSales.csv'

# %%
crash_df = sns.load_dataset('car_crashes')
crash_df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %% [markdown]
# # Distribution plot

# %%
sns.distplot(crash_df['not_distracted'], kde=False, bins=25)
# Out:
# C:\Users\Zygim\AppData\Local\Temp\ipykernel_8492\3409636794.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(crash_df['not_distracted'], kde=False, bins=25)
# <Axes: xlabel='not_distracted'>

# %% [markdown]
# # Joint plot

# %%
sns.jointplot(x='speeding', y='alcohol', data=crash_df, kind='hex')

# %% [markdown]
# # KDE plot

# %%
sns.kdeplot(crash_df['alcohol'])
# Out:
# <Axes: xlabel='alcohol', ylabel='Density'>

# %% [markdown]
# # Pair plot

# %%
# sns.pairplot(crash_df)

tips_df = sns.load_dataset('tips')
sns.pairplot(tips_df, hue='sex', palette='Blues')

# %% [markdown]
# # Rug plot

# %%
sns.rugplot(tips_df['tip'])
# Out:
# <Axes: xlabel='tip'>

# %% [markdown]
# # Styling

# %%
# sns.set_style('darkgrid')
# sns.set_style('whitegrid')
# sns.set_style('dark')
sns.set_style('ticks')

plt.figure(figsize=(8,4))

# sns.set_context('poster', font_scale=1.4)
# sns.set_context('talk', font_scale=1.4)
# sns.set_context('poster', font_scale=1.4)
sns.set_context('paper', font_scale=1.4)

sns.jointplot(x='speeding', y='alcohol', data=crash_df, kind='reg')

sns.despine(left=True, bottom=True, right=True, top=True)

# %% [markdown]
# # BAR PLOT

# %%
# sns.barplot(x='sex', y='total_bill', data=tips_df, estimator=np.median)
# sns.barplot(x='sex', y='total_bill', data=tips_df, estimator=np.std)
# sns.barplot(x='sex', y='total_bill', data=tips_df, estimator=np.var)
sns.barplot(x='sex', y='total_bill', data=tips_df, estimator=np.cov)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %% [markdown]
# # COUNT PLOT

# %%
sns.countplot(x='sex', data=tips_df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %% [markdown]
# # BOX PLOT

# %%
sns.boxplot(x='day', y='total_bill', data=tips_df, hue='sex')

plt.legend(lox=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[96], line 3
#       1 sns.boxplot(x='day', y='total_bill', data=tips_df, hue='sex')
# ----> 3 plt.legend(lox=0)
#
# File F:\DataSpell\Pandas_training\venv\Lib\site-packages\matplotlib\pyplot.py:3384, in legend(*args, **kwargs)
#    3382 @_copy_docstring_and_deprecators(Axes.legend)
#    3383 def legend(*args, **kwargs) -> Legend:
# -> 3384     return gca().legend(*args, **kwargs)
#
# File F:\DataSpell\Pandas_training\venv\Lib\site-packages\matplotlib\axes\_axes.py:323, in Axes.legend(self, *args, **kwargs)
#     206 """
#     207 Place a legend on the Axes.
#     208
#    (...)
#     320 .. plot:: gallery/text_labels_and_annotations/legend.py
#     321 """
#     322 handles, labels, kwargs = mlegend._parse_legend_args([self], *args, **kwargs)
# --> 323 self.legend_ = mlegend.Legend(self, handles, labels, **kwargs)
# ...

# %% [markdown]
# # VIOLIN PLOT

# %%
sns.violinplot(x='day', y='total_bill', data=tips_df, hue='sex', split=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # STRIP PLOT

# %%
plt.figure(figsize=(8,5))

sns.stripplot(x='day', y='total_bill', data=tips_df, jitter=True, hue='sex', dodge=True)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # SWARM PLOT

# %%
# sns.violinplot(x='day', y='total_bill', data=tips_df)
sns.swarmplot(x='day', y='total_bill', data=tips_df, color='red')
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # PALETTES

# %%
plt.figure(figsize=(10, 6))
sns.set_style('white')
sns.set_context('talk')
sns.stripplot(x='day', y='total_bill', data=tips_df, hue='sex', dodge=True, palette='magma')
plt.legend(loc=0)

# %% [markdown]
# # HEATMAPS

# %%
plt.figure(figsize=(10, 6))
sns.set_context('paper', font_scale=1.4)

crash_mx = crash_df.corr()

sns.heatmap(crash_mx, annot=True, cmap='coolwarm')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[103], line 4
#       1 plt.figure(figsize=(10, 6))
#       2 sns.set_context('paper', font_scale=1.4)
# ----> 4 crash_mx = crash_df.corr()
#       6 sns.heatmap(crash_mx, annot=True, cmap='coolwarm')
#
# File F:\DataSpell\Pandas_training\venv\Lib\site-packages\pandas\core\frame.py:11036, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11034 cols = data.columns
#   11035 idx = cols.copy()
# > 11036 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11038 if method == "pearson":
#   11039     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File F:\DataSpell\Pandas_training\venv\Lib\site-packages\pandas\core\frame.py:1981, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1979 if dtype is not None:
#    1980     dtype = np.dtype(dtype)
# ...

# %%
flights = sns.load_dataset('flights')
flights = flights.pivot_table(index='month', columns='year', values='passengers', observed=True)
sns.heatmap(flights, cmap='Blues', linecolor='white', linewidth=1)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %% [markdown]
# # CLUSTER MAP

# %%
iris = sns.load_dataset('iris')

species = iris.pop('species')
sns.clustermap(iris)

# %%
sns.clustermap(flights, cmap='Blue', standard_scale=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[117], line 1
# ----> 1 sns.clustermap(flights, cmap='Blue', standard_scale=1)
#
# File F:\DataSpell\Pandas_training\venv\Lib\site-packages\seaborn\matrix.py:1258, in clustermap(data, pivot_kws, method, metric, z_score, standard_scale, figsize, cbar_kws, row_cluster, col_cluster, row_linkage, col_linkage, row_colors, col_colors, mask, dendrogram_ratio, colors_ratio, cbar_pos, tree_kws, **kwargs)
#    1250     raise RuntimeError("clustermap requires scipy to be available")
#    1252 plotter = ClusterGrid(data, pivot_kws=pivot_kws, figsize=figsize,
#    1253                       row_colors=row_colors, col_colors=col_colors,
#    1254                       z_score=z_score, standard_scale=standard_scale,
#    1255                       mask=mask, dendrogram_ratio=dendrogram_ratio,
# ...

# %% [markdown]
# #  PAIR GRID

# %%
iris = sns.load_dataset('iris')
# iris_g = sns.PairGrid(iris, hue='species')
# iris_g.map(plt.scatter)
# iris_g.map_diag(plt.hist)
# # iris_g.map_offdiag(plt.scatter)
# 
# iris_g.map_upper(plt.scatter)
# iris_g.map_lower(sns.kdeplot)
iris_g = sns.PairGrid(iris, hue='species', x_vars=['sepal_length', 'sepal_width'], y_vars=['petal_length', 'petal_width'])
iris_g.map(plt.scatter)
iris_g.add_legend()

# %% [markdown]
# # FACET GRID

# %%
# tips_fg = sns.FacetGrid(data=tips_df, col='time', row='smoker', hue='smoker', height=4, aspect=1.3, 
#                         col_order=['Dinner', 'Lunch'], row_order=['Yes', 'No'], palette='magma')
# # tips_fg.map(plt.hist, 'total_bill', bins=8)
# tips_fg.map(plt.scatter, 'total_bill', 'tip')
# 

kws = dict(s=50, linewidth=0.5, edgecolor='black')
tips_fg = sns.FacetGrid(data=tips_df, col='sex', hue='smoker', height=4, aspect=1.3, hue_order=['Yes', 'No'], 
                        hue_kws=dict(marker=['^', 'v']), palette='magma')
tips_fg
